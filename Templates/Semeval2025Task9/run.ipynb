# %% [markdown]
# ##Sub-task 1

# %%
# %cd "/content/drive/MyDrive/Templates/Semeval2025Task9/CodeST1"
# !git clone https://github.com/NVIDIA/apex
# %cd apex
# !python3 setup.py install
# %cd "/content/drive/MyDrive/Templates/Semeval2025Task9/CodeST1"
# Out:
# /content/drive/MyDrive/Templates/Semeval2025Task9/CodeST1
# Cloning into 'apex'...
# remote: Enumerating objects: 11989, done.
# remote: Total 11989 (delta 0), reused 0 (delta 0), pack-reused 11989 (from 1)
# Receiving objects: 100% (11989/11989), 15.65 MiB | 14.22 MiB/s, done.
# Resolving deltas: 100% (8347/8347), done.
# Updating files: 100% (504/504), done.
# /content/drive/MyDrive/Templates/Semeval2025Task9/CodeST1/apex
#
#
# torch.__version__  = 2.5.1+cu124
#
#
# running install
# /usr/local/lib/python3.11/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
# ...

# %%
# !sh ../scripts/Run_ST1_Product_Cat.sh
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (4347 > 512). Running this sequence through the model will result in indexing errors
# Total samples:  5647
#
# Num seq that greater than max_len:  380
#
# 2025-02-28 11:24:19.486108: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740741859.512641   18271 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1740741859.521049   18271 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !sh ../scripts/Run_ST1_Hazard_Cat.sh
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (4347 > 512). Running this sequence through the model will result in indexing errors
# Total samples:  5647
#
# Num seq that greater than max_len:  380
#
# 2025-02-28 12:00:54.783261: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740744054.805657   27300 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1740744054.812381   27300 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python3 main.py --load_path_h ../Data/checkpoint_hazard_cat --load_path_p ../Data/checkpoint_product_cat
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (4347 > 512). Running this sequence through the model will result in indexing errors
# Total samples:  5647
#
# Num seq that greater than max_len:  380
#
# 2025-02-28 12:37:34.790177: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740746254.811269   36408 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1740746254.817750   36408 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [markdown]
# ##Sub-task 2

# %%
# %cd "/content/drive/MyDrive/Templates/Semeval2025Task9/CodeST2"
# !git clone https://github.com/NVIDIA/apex
# %cd apex
# !python3 setup.py install
# %cd "/content/drive/MyDrive/Templates/Semeval2025Task9/CodeST2"
# Out:
# /content/drive/MyDrive/Templates/Semeval2025Task9/CodeST2
# /content/drive/MyDrive/Templates/Semeval2025Task9/CodeST2/apex
#
#
# torch.__version__  = 2.5.1+cu124
#
#
# running install
# /usr/local/lib/python3.11/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /usr/local/lib/python3.11/dist-packages/setuptools/_distutils/cmd.py:66: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
# ...

# %%
# !sh ../scripts/Run_ST2_Product.sh
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (4347 > 512). Running this sequence through the model will result in indexing errors
# Total samples:  5647
#
# Num seq that greater than max_len:  380
#
# 2025-02-28 06:28:08.427239: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740724088.448346    8224 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1740724088.454970    8224 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !sh ../scripts/Run_ST2_Hazard.sh
# Out:
# config.json: 100% 570/570 [00:00<00:00, 3.80MB/s]
# tokenizer_config.json: 100% 48.0/48.0 [00:00<00:00, 226kB/s]
# vocab.txt: 100% 232k/232k [00:00<00:00, 1.07MB/s]
# tokenizer.json: 100% 466k/466k [00:00<00:00, 127MB/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (4347 > 512). Running this sequence through the model will result in indexing errors
# Total samples:  5647
#
# Num seq that greater than max_len:  380
#
# 2025-02-28 10:20:17.092564: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740738017.114851    1827 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...

# %%
# !python3 main.py --load_path_h ../Data/checkpoint_hazard --load_path_p ../Data/checkpoint_product
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (4347 > 512). Running this sequence through the model will result in indexing errors
# Total samples:  5647
#
# Num seq that greater than max_len:  380
#
# 2025-02-28 10:57:24.183849: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740740244.205099   11269 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1740740244.211586   11269 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [markdown]
# ##Submission file

# %%
import pandas as pd
import csv
import json

# %%
file1 = pd.read_csv('/content/drive/MyDrive/Templates/Semeval2025Task9/CodeST1/submissionST1.csv')
file2 = pd.read_csv('/content/drive/MyDrive/Templates/Semeval2025Task9/CodeST2/submissionST2.csv')
merged_file = pd.concat([file1, file2], axis=1)
merged_file.to_csv('/content/drive/MyDrive/Templates/Semeval2025Task9/submission.csv', index=False)

print("Merged file saved as 'submission.csv'")
# Out:
# Merged file saved as 'submission.csv'
